# %% [markdown]
# # Histogramas en Python

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
atletas=pd.read_csv ('C:/Users/pc/Archivos en Jupyter/Filtrando Información en Python/Corredores.csv', index_col=0)

# %%
atletas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, GBR to GER
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Corredor  1000 non-null   int64
#  1   Lugar     1000 non-null   int64
#  2   Genero    1000 non-null   object
#  3   Edad      1000 non-null   int64
#  4   Tiempo    1000 non-null   float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 46.9+ KB

# %%
atletas.head()
# Out:
#       Corredor  Lugar  Genero  Edad      Tiempo
# Pais
# GBR       3475   3592    Male    52  217.483333
# NY       13594  13853  Female    40  272.550000
# FRA      12012  12256    Male    31  265.283333
# MI       10236  10457  Female    33  256.150000
# NY        9476   9686    Male    33  252.250000

# %%
plt.hist(atletas['Tiempo'], 15, color="blue", ec="black")
# Out:
# (array([ 14.,  66., 159., 233., 220., 147.,  86.,  33.,  14.,  12.,   8.,
#           4.,   3.,   0.,   1.]),
#  array([147.3333333 , 175.29666663, 203.25999997, 231.2233333 ,
#         259.18666663, 287.14999997, 315.1133333 , 343.07666663,
#         371.03999997, 399.0033333 , 426.96666663, 454.92999997,
#         482.8933333 , 510.85666663, 538.81999997, 566.7833333 ]),
#  <BarContainer object of 15 artists>)

# %%
import seaborn as sns
sns.countplot(atletas['Tiempo'])
# Out:
# C:\Users\pc\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Tiempo', ylabel='count'>

# %%
grafico = sns.countplot (x='Genero', hue ='Tiempo', palette ='hot_r', data=atletas)
grafico.set (title='Tiempos por genero', xlabel ='Genero', ylabel='Total')
plt.show()
