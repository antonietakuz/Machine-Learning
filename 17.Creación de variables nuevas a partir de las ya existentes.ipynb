# %% [markdown]
# ## Creación de variables nuevas a partir de las ya existentes

# %% [markdown]
# #### 1. Carga de librerias y datos

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from matplotlib import rcParams
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
hidroponia= pd.read_csv('C:/Users/pc/Desktop/rociochavez/Rocio-Chavez-youtube-Files-master/Hidroponia_original.csv', index_col=0, encoding='latin-1')

# %%
hidroponia
# Out:
#                     pH           EC Hortaliza    Sistema Duracion_Ciclo
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5      Flor        NFT           70-90
# Calabacita           6   1.8 to 2.4     Fruto      Goteo              45
# Pepino        5 to 5.5     1.7 to 2     Fruto      Goteo           70-80
# Pimientos     5.5 to 6   0.8 to 1.8     Fruto      Goteo              65
# fresa                6   1.8 to 2.2     Fruto        NFT         120-150
# Tomate        6 to 6.5       2 to 4     Fruto      Goteo         110-120
# Albahaca      5.5 to 6     1 to 1.6      Hoja        NFT              90
# Repollo       6.5 to 7     2.5 to 3      Hoja        NFT          80-100
# Apio               6.5   1.8 to 2.4      Hoja        NFT          90-120
# Lechuga         6 to 7   1.2 to 1.8      Hoja        NFT           80-90
# Perejil       6 to 6.5   1.8 to 2.2      Hoja        NFT              80
# Rábano          6 to 7   1.4 to 1.8      Raiz  Aeroponia           60-70
# ...

# %%
hidroponia['Hort Sist']=hidroponia['Hortaliza'] + '-' + hidroponia['Sistema']
hidroponia
# Out:
#                     pH           EC Hortaliza    Sistema Duracion_Ciclo   \
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5      Flor        NFT           70-90
# Calabacita           6   1.8 to 2.4     Fruto      Goteo              45
# Pepino        5 to 5.5     1.7 to 2     Fruto      Goteo           70-80
# Pimientos     5.5 to 6   0.8 to 1.8     Fruto      Goteo              65
# fresa                6   1.8 to 2.2     Fruto        NFT         120-150
# Tomate        6 to 6.5       2 to 4     Fruto      Goteo         110-120
# Albahaca      5.5 to 6     1 to 1.6      Hoja        NFT              90
# Repollo       6.5 to 7     2.5 to 3      Hoja        NFT          80-100
# Apio               6.5   1.8 to 2.4      Hoja        NFT          90-120
# Lechuga         6 to 7   1.2 to 1.8      Hoja        NFT           80-90
# Perejil       6 to 6.5   1.8 to 2.2      Hoja        NFT              80
# Rábano          6 to 7   1.4 to 1.8      Raiz  Aeroponia           60-70
# ...

# %% [markdown]
# #### 2. Conversion de variables Ordinales a numerica

# %%
#Creamos un diccionario con los valores que queremos asignar

diccionario={'Aeroponia': 1, 'Goteo': 2, 'NFT': 3}
hidroponia['Sistema Costo']=hidroponia['Sistema'].replace(diccionario)
hidroponia
# Out:
#                     pH           EC Hortaliza    Sistema Duracion_Ciclo   \
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5      Flor        NFT           70-90
# Calabacita           6   1.8 to 2.4     Fruto      Goteo              45
# Pepino        5 to 5.5     1.7 to 2     Fruto      Goteo           70-80
# Pimientos     5.5 to 6   0.8 to 1.8     Fruto      Goteo              65
# fresa                6   1.8 to 2.2     Fruto        NFT         120-150
# Tomate        6 to 6.5       2 to 4     Fruto      Goteo         110-120
# Albahaca      5.5 to 6     1 to 1.6      Hoja        NFT              90
# Repollo       6.5 to 7     2.5 to 3      Hoja        NFT          80-100
# Apio               6.5   1.8 to 2.4      Hoja        NFT          90-120
# Lechuga         6 to 7   1.2 to 1.8      Hoja        NFT           80-90
# Perejil       6 to 6.5   1.8 to 2.2      Hoja        NFT              80
# Rábano          6 to 7   1.4 to 1.8      Raiz  Aeroponia           60-70
# ...

# %%
#Eliminamos las columnas que ya no necesitamos
hidroponia2 = hidroponia.drop(['Hortaliza', 'Sistema'], axis=1)
hidroponia2
# Out:
#                     pH           EC Duracion_Ciclo        Hort Sist  \
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5           70-90        Flor-NFT
# Calabacita           6   1.8 to 2.4              45     Fruto-Goteo
# Pepino        5 to 5.5     1.7 to 2           70-80     Fruto-Goteo
# Pimientos     5.5 to 6   0.8 to 1.8              65     Fruto-Goteo
# fresa                6   1.8 to 2.2         120-150       Fruto-NFT
# Tomate        6 to 6.5       2 to 4         110-120     Fruto-Goteo
# Albahaca      5.5 to 6     1 to 1.6              90        Hoja-NFT
# Repollo       6.5 to 7     2.5 to 3          80-100        Hoja-NFT
# Apio               6.5   1.8 to 2.4          90-120        Hoja-NFT
# Lechuga         6 to 7   1.2 to 1.8           80-90        Hoja-NFT
# Perejil       6 to 6.5   1.8 to 2.2              80        Hoja-NFT
# Rábano          6 to 7   1.4 to 1.8           60-70  Raiz-Aeroponia
# Espinacas       6 to 7   1.8 to 2.3              75        Hoja-NFT
# ...

# %% [markdown]
# #### 3. Multiplicacion de los valores de dos o mas variables existentes

# %%
import pandas as pd

df = pd.DataFrame({'A': ['foo', 'bar', 'baz'], 'B': ['foobar', 'barbaz', 'quxqux']})

# Check if the substring 'bar' is present in column 'B'
df['B_has_substring'] = df['B'].str.contains('bar')

print(df)
# Out:
#      A       B  B_has_substring
# 0  foo  foobar             True
# 1  bar  barbaz             True
# 2  baz  quxqux            False

# %%
hidroponia2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15 entries, Brócoli to Cebollín
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pH               15 non-null     object
#  1   EC               15 non-null     object
#  2   Duracion_Ciclo   15 non-null     object
#  3   Hort Sist        15 non-null     object
#  4   Sistema Costo    15 non-null     int64
#  5   Duracion         15 non-null     bool
#  6   Hort Sist2       15 non-null     object
# dtypes: bool(1), int64(1), object(5)
# memory usage: 855.0+ bytes

# %%
#creamos una variable llamada duración para detectar los cultivos que podrían durar 100 dias o mas
hidroponia2['Hort Sist2']=hidroponia2['Hort Sist'].str.contains('Flor-NFT')
hidroponia2
# Out:
#                     pH           EC Duracion_Ciclo        Hort Sist  \
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5           70-90        Flor-NFT
# Calabacita           6   1.8 to 2.4              45     Fruto-Goteo
# Pepino        5 to 5.5     1.7 to 2           70-80     Fruto-Goteo
# Pimientos     5.5 to 6   0.8 to 1.8              65     Fruto-Goteo
# fresa                6   1.8 to 2.2         120-150       Fruto-NFT
# Tomate        6 to 6.5       2 to 4         110-120     Fruto-Goteo
# Albahaca      5.5 to 6     1 to 1.6              90        Hoja-NFT
# Repollo       6.5 to 7     2.5 to 3          80-100        Hoja-NFT
# Apio               6.5   1.8 to 2.4          90-120        Hoja-NFT
# Lechuga         6 to 7   1.2 to 1.8           80-90        Hoja-NFT
# Perejil       6 to 6.5   1.8 to 2.2              80        Hoja-NFT
# Rábano          6 to 7   1.4 to 1.8           60-70  Raiz-Aeroponia
# Espinacas       6 to 7   1.8 to 2.3              75        Hoja-NFT
# ...

# %%
for i in range(hidroponia2.shape[0]):
    if hidroponia2.iloc[i, 6]:
        hidroponia2.iloc[i,6]=2
    else:
        hidroponia2.iloc[i,6]=1
hidroponia2
# Out:
#                     pH           EC Duracion_Ciclo        Hort Sist  \
# Cultivo
# Brócoli       6 to 6.8   2.8 to 3.5           70-90        Flor-NFT
# Calabacita           6   1.8 to 2.4              45     Fruto-Goteo
# Pepino        5 to 5.5     1.7 to 2           70-80     Fruto-Goteo
# Pimientos     5.5 to 6   0.8 to 1.8              65     Fruto-Goteo
# fresa                6   1.8 to 2.2         120-150       Fruto-NFT
# Tomate        6 to 6.5       2 to 4         110-120     Fruto-Goteo
# Albahaca      5.5 to 6     1 to 1.6              90        Hoja-NFT
# Repollo       6.5 to 7     2.5 to 3          80-100        Hoja-NFT
# Apio               6.5   1.8 to 2.4          90-120        Hoja-NFT
# Lechuga         6 to 7   1.2 to 1.8           80-90        Hoja-NFT
# Perejil       6 to 6.5   1.8 to 2.2              80        Hoja-NFT
# Rábano          6 to 7   1.4 to 1.8           60-70  Raiz-Aeroponia
# Espinacas       6 to 7   1.8 to 2.3              75        Hoja-NFT
# ...
